# %%
# Config Box

d = {"key": "value", "key1": "value1"}

# %%
d.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 d.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
from box import ConfigBox

d2 = ConfigBox({"key": "value", "key1": "value1"})

# %%
d2.key
# Out:
# 'value'

# %%
type(d2)
# Out:
# box.config_box.ConfigBox

# %% [markdown]
# # ensure annotations

# %%
def get_product(x: int, y:int) -> int:
    return x * y

# %%
get_product(x=2, y=5)
# Out:
# 10

# %%
get_product(x=2, y='5')
# Out:
# '55'

# %%
from ensure import ensure_annotations

@ensure_annotations
def get_prodict(x: int, y:int) -> int:
    return x * y

# %%
get_prodict(x=2, y="5")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 get_prodict(x=2, y="5")
#
# File c:\Users\naman\DL_Projects\Kidney-Disease-Classification-Deep-Learning-Project\kidneyENV\Lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_prodict at 0x0000028ADF419A80> does not match annotation type <class 'int'>

# %% [markdown]
# ## Download the data from the google drive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1XyUz-wDb0iL8Sz4vzUEgYCNfKXKtgJo9/view?usp=sharing"

# %%
url.split("/")
# Out:
# ['https:',
#  '',
#  'drive.google.com',
#  'file',
#  'd',
#  '1XyUz-wDb0iL8Sz4vzUEgYCNfKXKtgJo9',
#  'view?usp=sharing']

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1XyUz-wDb0iL8Sz4vzUEgYCNfKXKtgJo9'

# %% [markdown]
# ## File is too large then it will not be download.

# %%
prefix = "https://drive.google.com/uc?export=download&id="
gdown.download(prefix + file_id, output="data.zip", quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1XyUz-wDb0iL8Sz4vzUEgYCNfKXKtgJo9
# From (redirected): https://drive.google.com/uc?id=1XyUz-wDb0iL8Sz4vzUEgYCNfKXKtgJo9&confirm=t&uuid=7df07160-3056-4e90-865f-01a5f8dc5e6c
# To: c:\Users\naman\DL_Projects\Kidney-Disease-Classification-Deep-Learning-Project\research\data.zip
# 100%|██████████| 248M/248M [00:06<00:00, 36.3MB/s]
# 'data.zip'
